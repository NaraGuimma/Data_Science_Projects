# %% [markdown]
# ### Datathon
#
# Este é um notebook exemplo para leitura de dados no formato parquet para um dataframe pandas.

# %%
# !pip install pyarrow
# !pip install pandas

# %%
#import das bibliotecas
import pandas as pd

# %%
#leitura de um arquivo parquet utilizando pyarrow, criando um dataframe pandas

#altere o <dir> para os diretório que contém os arquivos parquet que deseja analisar
#exemplo: files = r'/mnt/c/Users/Monique/datathon/tb_cnes_estabelecimentos/'

files = r'<dir>'
df = pd.read_parquet(files, engine='pyarrow')

#criado o dataframe df

# %%
#visualizando os primeiros dados do dataframe
df.head()
# Out:
#       CO_UNIDADE  CO_CNES NU_CNPJ_MANTENEDORA TP_PFPJ NIVEL_DEP  \
# 0  3556205173388  5173388                None       1         1
# 1  4306102263483  2263483                None       3         1
# 2  4314409891307  9891307                None       1         1
# 3  5107959088326  9088326                None       3         1
# 4  5107959306048  9306048                None       3         1
#
#                                NO_RAZAO_SOCIAL  \
# 0                SILVIO MAURICIO RINHEL VIRDES
# 1  LABORATORIO DE ANALISES CLINICAS BISSO LTDA
# 2                 ANA CAROLINA AZEREDO TESSARO
# 3                  SALES SAAD SOCIEDADE MEDICA
# 4              ARAUJO LACERDA SOCIEDADE MEDICA
#
#                        NO_FANTASIA                            NO_LOGRADOURO  \
# 0    SILVIO MAURICIO RINHEL VIRDES                           RUA 13 DE MAIO
# 1           LABORATORIO BISSO LTDA                      RUA CORONEL MARTINS
# ...

# %%
#visualizando a estrutura do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418045 entries, 0 to 418044
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   CO_UNIDADE                   418045 non-null  object
#  1   CO_CNES                      418045 non-null  object
#  2   NU_CNPJ_MANTENEDORA          101945 non-null  object
#  3   TP_PFPJ                      418045 non-null  object
#  4   NIVEL_DEP                    418045 non-null  object
#  5   NO_RAZAO_SOCIAL              418043 non-null  object
#  6   NO_FANTASIA                  418023 non-null  object
#  7   NO_LOGRADOURO                418044 non-null  object
#  8   NU_ENDERECO                  417756 non-null  object
#  9   NO_COMPLEMENTO               187219 non-null  object
#  10  NO_BAIRRO                    418043 non-null  object
#  11  CO_CEP                       418045 non-null  object
# ...
